# %%
# !ls
# Out:
# LICENSE          demo01.ipynb     models           visualize.ipynb
# README.md        exp              requirements.txt
# checkpoints      img              scripts
# data             main_informer.py utils

# %%
import pandas as pd

df = pd.read_csv("data/ETT/ETTh1.csv")
df.head()
# Out:
#                   date   HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# 0  2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 1  2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2  2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 3  2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 4  2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
df_skip = df[::100]
df_skip.head()
# Out:
#                     date    HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# 0    2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 100  2016-07-05 04:00:00  11.320  5.626  7.676  2.630  3.046  1.888  30.459999
# 200  2016-07-09 08:00:00  11.454  3.416  8.280  1.102  3.137  1.767  28.771999
# 300  2016-07-13 12:00:00   8.774  2.143  5.721  0.426  2.650  1.005  32.852001
# 400  2016-07-17 16:00:00   7.703  2.143  5.472  1.066  2.224  0.975  37.987000

# %%
df_skip.plot(x='date',figsize=(20,10),xlabel="ETTh1")
# Out:
# <AxesSubplot:xlabel='ETTh1'>

# %%
df = pd.read_csv("data/ETT/ETTh2.csv")
df = df[::100]
df.plot(x='date',figsize=(20,10),xlabel="ETTh2")
# Out:
# <AxesSubplot:xlabel='ETTh2'>

# %%
df = pd.read_csv("data/ETT/ETTm1.csv")
df = df[::100]
df.plot(x='date',figsize=(20,10),xlabel="ETTm1")
# Out:
# <AxesSubplot:xlabel='ETTm1'>
