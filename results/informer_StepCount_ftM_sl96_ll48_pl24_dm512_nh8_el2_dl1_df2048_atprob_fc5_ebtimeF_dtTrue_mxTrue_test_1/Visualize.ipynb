# %%
import numpy as np
import matplotlib.pyplot as plt

pred = np.load("real_prediction.npy")

true = np.load("real_prediction_trues.npy")

# %%
pred.shape
# Out:
# (1, 24, 2)

# %%
index = 1
pred0 = pred[0]
true0 = true[0]
pred24 = [pred0[i][index] for i in range(24)]
true24 = [true0[i][index] for i in range(24)]
pred24
# Out:
# [0.051764354,
#  -0.00804536,
#  0.09548756,
#  -0.114074625,
#  -0.17825153,
#  -0.19307259,
#  -0.3082705,
#  -0.26322687,
#  -0.24431661,
#  -0.31208783,
#  -0.21961099,
#  -0.28044075,
#  -0.24429661,
#  -0.22243342,
#  -0.204245,
#  -0.058649503,
#  -0.048445985,
#  -0.010252088,
#  -0.05781409,
#  -0.0071314275,
#  0.08155313,
#  0.021310054,
#  0.036941342,
#  0.056737095]

# %%
plt.plot(pred24,linestyle = "dotted",label = "prediction")
plt.plot(true24,label = "true")
plt.legend()
plt.savefig("informer_StepCount_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_1.png", dpi=300)
