# %%
import numpy as np

attention = np.load('attention_weight.npy')

# %%
attention.shape
# Out:
# (1, 96, 96, 70)

# %%
attention = attention[0]
attention.shape
# Out:
# (96, 96, 70)

# %%
attention = attention[-2]
attention.shape
# Out:
# (96, 70)

# %%
attention
# Out:
# array([[-0.01991136,  0.03098795,  0.18164767, ...,  0.19653496,
#          0.01015269, -1.1610914 ],
#        [-0.03760481,  0.04648261,  0.01990853, ...,  0.07868243,
#          0.00885687, -1.2155147 ],
#        [ 0.02866793,  0.03533272,  0.34984872, ...,  0.34775245,
#          0.01389102, -1.055375  ],
#        ...,
#        [-0.09539304, -0.01200824,  0.13296922, ...,  0.07810034,
#          0.0066911 , -1.3401448 ],
#        [-0.07505061, -0.00799683,  0.04655848, ...,  0.07031437,
#          0.00685674, -1.3627138 ],
#        [-0.07279093,  0.00518455, -0.01930454, ...,  0.03155997,
#          0.00709707, -1.4048789 ]], dtype=float32)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,10))
plt.imshow(attention)
plt.title("2D attention")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %matplotlib notebook


x = np.arange(len(attention[0]))
y = np.arange(len(attention))

X, Y = np.meshgrid(x, y)

fig = plt.figure()
ax = Axes3D(fig)
surf = ax.plot_surface(X, Y, np.array(attention))
# Out:
# <img src="data:image/png;base64,..." width="640">
