# %%
import numpy as np

attention = np.load('attention_weight.npy')

# %%
attention.shape
# Out:
# (1, 8, 96, 49)

# %%
attention = attention[0]
attention.shape
# Out:
# (8, 96, 49)

# %%
attention  = np.sum(attention,axis=0)
attention.shape
# Out:
# (96, 49)

# %%
attention  = np.sum(attention,axis=1)
attention.shape
# Out:
# (96,)

# %%
attention
# Out:
# array([-297.03952 , -351.91382 , -473.97458 , -398.79385 , -388.79443 ,
#        -325.12723 , -289.2785  , -176.3248  , -151.00302 , -273.3614  ,
#        -236.58496 , -176.10994 ,   82.81756 ,   50.469482,   27.957012,
#        -103.31617 , -138.88927 ,  -44.811127, -365.83124 , -191.87231 ,
#        -221.08704 , -213.93646 , -236.01955 , -270.7431  ,  322.83752 ,
#         350.45853 ,  204.22621 ,  170.13382 ,  230.20284 ,  317.89154 ,
#         113.58714 , -245.5677  ,  -79.21473 ,  -97.519585,  -91.66816 ,
#         -49.53118 ,  115.4483  ,  185.41678 ,  122.19537 ,  222.47755 ,
#          86.624   ,  205.20975 ,  180.29385 ,  186.15283 ,  136.21819 ,
#         172.0932  ,   72.48386 ,   76.28213 , -367.22278 , -665.7639  ,
#        -460.5313  , -304.29144 ,  -61.483944,  203.0564  ,  341.0017  ,
#         317.6747  ,  572.14685 ,  664.8162  ,  733.61053 ,  714.67456 ,
#         558.7016  ,  728.00507 ,  508.94882 ,  377.4835  ,  208.6637  ,
#          28.831173,  -84.41728 ,  -73.37135 , -269.05267 , -397.78558 ,
#        -469.22    , -491.70096 , -155.87448 , -273.34558 ,  -91.437225,
#         -73.42764 ,  185.68425 ,  183.98453 ,  286.43683 ,  417.43024 ,
#         634.5589  ,  690.74646 ,  744.06604 ,  756.41174 ,  661.7969  ,
#         733.308   ,  536.03687 ,  411.01645 ,  241.06927 ,  239.34946 ,
#         -31.498692, -164.09938 , -255.81703 , -361.2918  , -478.1101  ,
#        -529.0851  ], dtype=float32)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(attention)

# %%
target = np.load('attention_target.npy')
target.shape
target = target[0,:,0]

# plt.plot(attention,linestyle = "dotted",label = "attention_weight")
plt.plot(target,label = "target_value")
plt.legend()
# plt.savefig".png", dpi=300)

# %%
min = attention.min(axis=0, keepdims=True)
max = attention.max(axis=0, keepdims=True)
attention = (attention-min)/(max-min)
plt.plot(attention)

# %%
min = target.min(axis=0, keepdims=True)
max = target.max(axis=0, keepdims=True)
target = (target-min)/(max-min)
plt.plot(target)

# %%
plt.plot(attention,linestyle = "dotted",label = "attention_weight")
plt.plot(target,label = "target_value")
plt.legend()
