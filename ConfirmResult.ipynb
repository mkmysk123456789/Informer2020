# %%
# !cd results/informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0

# %%
# !pwd
# Out:
# /home/mikami/B4/Repositories/Informer2020

# %%
import numpy as np

# %%
pred = \
np.load("results/informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0/pred.npy")

# %%
print(pred)
# Out:
# [[[ 0.3611488   0.49717012  0.5053047  ... -0.7202359   0.44382682
#    -0.7755261 ]
#   [ 0.43981344  0.41497827  0.5803931  ... -0.56752056  0.43452746
#    -0.6991967 ]
#   [ 0.40529057  0.4430126   0.5558489  ... -0.6268039   0.54018456
#    -0.8233507 ]
#   ...
#   [ 0.09901185 -0.45241195  0.12156845 ... -0.05387475  0.2931126
#    -0.44466963]
#   [ 0.12142958 -0.35387796  0.16780405 ... -0.1273189   0.28194955
#    -0.4724865 ]
#   [ 0.14397837 -0.24952385  0.20534435 ... -0.21332768  0.26285028
#    -0.5005373 ]]
#
#  [[ 0.32437342  0.58639777  0.46110958 ... -0.5766582   0.4211
#    -0.7513603 ]
#   [ 0.44411767  0.5160351   0.53521603 ... -0.4335115   0.3895681
#    -0.76670307]
#   [ 0.39642802  0.5356914   0.53188944 ... -0.515811    0.46606
#    -0.81417257]
#   ...
#   [ 0.35621196 -0.19946244  0.39284047 ... -0.07361531  0.16355057
#    -0.48472375]
#   [ 0.40417454 -0.03075849  0.4710488  ... -0.16639645  0.1587062
#    -0.51286614]
# ...

# %%
print(pred.shape)
# Out:
# (2848, 24, 7)

# %%
print(pred[0][0])
# Out:
# [ 0.3611488   0.49717012  0.5053047   0.44267824 -0.7202359   0.44382682
#  -0.7755261 ]

# %%
true =\
np.load("results/informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0/true.npy")

# %%
pred_extract = []
true_extract = []
for i in range(2848):
    for j in range(24):
        pred_extract.append(pred[i][j][6])
        true_extract.append(pred[i][j][6])

# %%
print(len(pred_extract))
# Out:
# 68352

# %%
print(len(true_extract))
# Out:
# 68352

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 4)

# %%
plt.figure(figsize=(40, 20))
# plt.plot(pred_extract[::100])
plt.plot(true_extract[::100])
plt.show()

# %%
pred = np.array(pred_extract)
true = np.array(true_extract)
pred-true
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
print(sum(abs(pred-true)))
# Out:
# 0.0

# %%
# !cd results/informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_1/real
